# %%
import re
import pandas as pd

# %%
label_map = {}
with open(r'./uchoice-Instacart-labels.txt',encoding='utf-8') as labels:
    while line := labels.readline():
        matches = re.findall(r'(\d+) (.*)', line)
        if matches:
            label_map[int(matches[0][0])] = matches[0][1]

# %%
df = pd.DataFrame(columns=['basket_id','basket'])

# %%
with open(r'./uchoice-Instacart-5-25.txt', encoding='utf-8') as carts:
    cart_id = 0 
    while line := carts.readline():
        df = pd.concat(
            [
                df, 
                pd.DataFrame(
                    columns=['basket_id', 'basket'], 
                    data=((cart_id, 
                    [label_map.get(int(product)) for product in line.strip().split(' ') if int(product) in label_map]
                   ),)
                )
            ]
        )
        cart_id += 1
